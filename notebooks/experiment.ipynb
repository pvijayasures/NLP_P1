# %%
from src.features import prepare_features
from src.config import TRAIN_PROCESSED_FILE

# %%
X, y, vectorizer, train_df = prepare_features(TRAIN_PROCESSED_FILE)

# %%
import pandas as pd
from pathlib import Path
import joblib

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from sklearn.model_selection import train_test_split

from src.config import (
    PROCESSED_PATH,
    TRAIN_PROCESSED_FILE,
    MODELS_PATH,
    CLEAN_TEXT_COLUMN,
    LABEL_COLUMN,
    MODEL_FILE,
    TEST_SIZE,
    RANDOM_STATE
)

# %%
def train_model(X, y):
    """Train baseline logistic regression model."""

    model = LogisticRegression(
        max_iter=1000,
        class_weight="balanced"
    )

    model.fit(X, y)

    return model

# %%
def evaluate_model(model, X_test, y_test):
    """Evaluate trained model."""

    preds = model.predict(X_test)

    print("\nAccuracy:", accuracy_score(y_test, preds))
    print("\nClassification Report:\n")
    print(classification_report(y_test, preds))

# %%
X_train, X_test, y_train, y_test = train_test_split(
        X,
        y,
        test_size=TEST_SIZE,
        random_state=RANDOM_STATE,
        stratify=y
    )

# %%
model = train_model(X_train, y_train)
evaluate_model(model, X_test, y_test)
# Out:
# Accuracy: 0.9298762337458875
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96     28670
#            1       0.61      0.86      0.71      3245
#
#     accuracy                           0.93     31915
#    macro avg       0.80      0.90      0.84     31915
# weighted avg       0.95      0.93      0.94     31915
